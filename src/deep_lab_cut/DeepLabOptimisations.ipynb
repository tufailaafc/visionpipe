# %% [markdown]
# Upon inspection I have noticed a pattern of when a point is off it is massively off.
#
#
# First idea:
# generate a safe ratio for the difference between all of the parts
# ie
# take the length of each part of the skeleton from a representitive pig.
